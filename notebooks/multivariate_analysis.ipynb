# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/ryansteele/my_repo2/my_project3/data/matchups/matchups_all_seasons.csv")

df.head()
# Out:
#      gamekey                 date  seasontype  season  week team opponent  \
# 0  202210132  2022-09-08T20:20:00           1    2022     1  LAR      BUF
# 1  202210113  2022-09-11T13:00:00           1    2022     1  HOU      IND
# 2  202210107  2022-09-11T13:00:00           1    2022     1  CIN      PIT
# 3  202210105  2022-09-11T13:00:00           1    2022     1  CAR      CLE
# 4  202210135  2022-09-11T13:00:00           1    2022     1  WAS      JAX
#
#   home_away  points_for  points_against  ...  opp_rolling_point_diff_3  \
# 0      HOME          10              31  ...                       NaN
# 1      HOME          20              20  ...                       NaN
# 2      HOME          20              23  ...                       NaN
# 3      HOME          24              26  ...                       NaN
# 4      HOME          28              22  ...                       NaN
#
#   opp_rolling_yards_total_3  opp_rolling_yards_allowed_3  \
# ...

# %%
corr = df.corr(numeric_only=True)['target_next_point_diff'].sort_values(ascending=False)
corr.head(10)
# Out:
# target_next_point_diff                1.000000
# rolling_win_rate_5                    0.258413
# rolling_point_diff_3                  0.181816
# rolling_turnover_diff_3               0.138269
# rolling_points_for_3                  0.136485
# cumulative_wins                       0.127421
# rolling_yards_total_3                 0.127130
# passingyardsperattempt                0.124105
# opp_opponentpassingyardsperattempt    0.124105
# rolling_third_down_pct_3              0.123833
# Name: target_next_point_diff, dtype: float64

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='rolling_point_diff_3', y='target_next_point_diff')
plt.title("Rolling 3-Game Point Diff vs Future Point Diff")
plt.xlabel("Rolling Point Diff (Past 3 Games)")
plt.ylabel("Next Game Point Diff")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x='home', y='point_diff')
plt.title("Home vs Away — Effect on Point Differential")
plt.xlabel("Home (1 = Yes, 0 = Away)")
plt.ylabel("Next Game Point Differential")
plt.show()
