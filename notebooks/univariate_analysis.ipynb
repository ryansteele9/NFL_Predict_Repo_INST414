# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("/Users/ryansteele/my_repo2/my_project3/data/matchups/matchups_all_seasons.csv")

df.head()
# Out:
#      gamekey                 date  seasontype  season  week team opponent  \
# 0  202210132  2022-09-08T20:20:00           1    2022     1  LAR      BUF
# 1  202210113  2022-09-11T13:00:00           1    2022     1  HOU      IND
# 2  202210107  2022-09-11T13:00:00           1    2022     1  CIN      PIT
# 3  202210105  2022-09-11T13:00:00           1    2022     1  CAR      CLE
# 4  202210135  2022-09-11T13:00:00           1    2022     1  WAS      JAX
#
#   home_away  points_for  points_against  ...  opp_rolling_point_diff_3  \
# 0      HOME          10              31  ...                       NaN
# 1      HOME          20              20  ...                       NaN
# 2      HOME          20              23  ...                       NaN
# 3      HOME          24              26  ...                       NaN
# 4      HOME          28              22  ...                       NaN
#
#   opp_rolling_yards_total_3  opp_rolling_yards_allowed_3  \
# ...

# %%
important_features = [
    'point_diff', 'target_next_point_diff', 'rolling_points_for_3',
    'rolling_point_diff_3', 'rolling_turnover_diff_3',
    'rolling_win_rate_5', 'offensiveyards', 'turnover_diff'
]

df[important_features].describe().T
# Out:
#                          count        mean        std     min      25%    50%  \
# point_diff               925.0    2.354595  13.764473 -40.000   -6.000    2.0
# target_next_point_diff   862.0   -0.808585  14.064949 -50.000   -8.000   -1.0
# rolling_points_for_3     733.0   22.206412   6.554550   6.700   17.300   21.3
# rolling_point_diff_3     733.0   -0.231787   8.965207 -24.300   -6.300   -0.7
# rolling_turnover_diff_3  733.0    0.006371   1.029146  -3.333   -0.667    0.0
# rolling_win_rate_5       603.0    0.490879   0.263568   0.000    0.200    0.4
# offensiveyards           925.0  342.775135  81.944980   0.000  289.000  348.0
# turnover_diff            925.0    0.065946   1.729855  -6.000   -1.000    0.0
#
#                              75%      max
# point_diff                10.000   50.000
# target_next_point_diff     7.000   42.000
# rolling_points_for_3      27.000   42.300
# rolling_point_diff_3       6.000   30.000
# rolling_turnover_diff_3    0.667    3.333
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['target_next_point_diff'], kde=True, bins=30)
plt.title("Distribution of Next Game Point Differential")
plt.xlabel("Next Game Point Diff")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['rolling_points_for_3'], kde=True, bins=30)
plt.title("Rolling 3-Game Average Points Scored")
plt.xlabel("Rolling Points (3 games)")
plt.ylabel("Frequency")
plt.show()
