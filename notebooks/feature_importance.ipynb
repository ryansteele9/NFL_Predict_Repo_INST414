# %%
from xgboost import plot_importance
import matplotlib.pyplot as plt
import pickle

with open("/Users/ryansteele/my_repo2/models/xgb_point_diff.pkl", "rb") as f:
    obj = pickle.load(f)

model = obj["model"]

plot_importance(model, max_num_features=15, importance_type="gain")
plt.title("Top Features by Gain")
plt.show()
