# %%
import pandas as pd

df = pd.read_csv("/Users/ryansteele/my_repo2/data/processed/matchups/matchups_all_seasons.csv")

df[['vegas_spread','vegas_total','home_moneyline','away_moneyline','home_implied_prob']].isna().sum()
# Out:
# vegas_spread         0
# vegas_total          0
# home_moneyline       0
# away_moneyline       0
# home_implied_prob    0
# dtype: int64
